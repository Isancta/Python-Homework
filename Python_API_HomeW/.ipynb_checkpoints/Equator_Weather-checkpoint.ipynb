# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests 
import json
import random
import time

# %%
#Incorporate API key
api_key="378f0478b1618fbfb1b707c5f8eaaa9f"

# %%
# Incorporate citipy to determine city based on latitude and Longitude
from citipy import citipy

# %%
#Create output path
equatorby_data="output_data/cities.csv"

# %%
#Define study range for Latitude&Longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
   
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
#Performe a weather check on each city using a series of successive API calls
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "Imperial"
query_url =f"{url}appid={api_key}&units={units}&q=" 

citydata = []
#Targets:loop through the list of cities and perform a request for data on each to get each city weather data
for city in cities:
    response = requests.get(query_url+city).json()
    try:
        print(json.dumps(response, indent=4, sort_keys=True))
    
        lat = response["coord"]["lat"]
        lngs=response["coord"]["lon"]
        humidity=response["main"]["humidity"]
        Max_temp=response["main"]["temp_max"]
        Wind_speed=response["wind"]["speed"]
        Date=response["dt"]
    
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    Record={"city":city, "date":Date,"latitude":lat,"longitude":lngs,"Humidity":humidity,"Max_temp":Max_temp,"Wind_speed":Wind_speed}
    citydata.append(Record)
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1564246152,
#     "id": 6201424,
#     "main": {
#         "humidity": 93,
#         "pressure": 1020,
#         "temp": 46,
#         "temp_max": 46,
#         "temp_min": 46
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "message": 0.007,
#         "sunrise": 1564258226,
#         "sunset": 1564291887,
#         "type": 3
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 351,
#         "gust": 2.68,
#         "speed": 3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 19
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1564246152,
#     "id": 4030556,
#     "main": {
#         "grnd_level": 1019.07,
#         "humidity": 81,
#         "pressure": 1019.27,
#         "sea_level": 1019.27,
#         "temp": 74.03,
#         "temp_max": 74.03,
#         "temp_min": 74.03
#     },
#     "name": "Rikitea",
#     "rain": {
#         "3h": 0.313
#     },
#     "sys": {
#         "country": "PF",
#         "message": 0.0138,
#         "sunrise": 1564241795,
#         "sunset": 1564281356
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 340.787,
#         "speed": 9.48
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 86
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.43,
#         "lon": 74.48
#     },
#     "dt": 1564246153,
#     "id": 1257198,
#     "main": {
#         "grnd_level": 972.24,
#         "humidity": 62,
#         "pressure": 996.43,
#         "sea_level": 996.43,
#         "temp": 88.79,
#         "temp_max": 88.79,
#         "temp_min": 88.79
#     },
#     "name": "Sardarshahr",
#     "sys": {
#         "country": "IN",
#         "message": 0.0063,
#         "sunrise": 1564186837,
#         "sunset": 1564235779
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 84.194,
#         "speed": 11.34
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.05,
#         "lon": -84.5
#     },
#     "dt": 1564246153,
#     "id": 4297983,
#     "main": {
#         "humidity": 48,
#         "pressure": 1026,
#         "temp": 84.87,
#         "temp_max": 89.01,
#         "temp_min": 82
#     },
#     "name": "Lexington",
#     "sys": {
#         "country": "US",
#         "id": 5668,
#         "message": 0.0089,
#         "sunrise": 1564223783,
#         "sunset": 1564275143,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "haze",
#             "icon": "50d",
#             "id": 721,
#             "main": "Haze"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.88,
#         "lon": 147.33
#     },
#     "dt": 1564246143,
#     "id": 2163355,
#     "main": {
#         "humidity": 75,
#         "pressure": 1018,
#         "temp": 43.12,
#         "temp_max": 46,
#         "temp_min": 39.99
#     },
#     "name": "Hobart",
#     "sys": {
#         "country": "AU",
#         "id": 9545,
#         "message": 0.0085,
#         "sunrise": 1564262834,
#         "sunset": 1564297614,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 11.45,
#         "lon": -11.68
#     },
#     "dt": 1564246154,
#     "id": 2414545,
#     "main": {
#         "grnd_level": 925.14,
#         "humidity": 96,
#         "pressure": 1011.35,
#         "sea_level": 1011.35,
#         "temp": 70.61,
#         "temp_max": 70.61,
#         "temp_min": 70.61
#     },
#     "name": "Tougue",
#     "rain": {
#         "3h": 6.876
#     },
#     "sys": {
#         "country": "GN",
#         "message": 0.0076,
#         "sunrise": 1564209196,
#         "sunset": 1564254777
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 345.359,
#         "speed": 4.47
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 48
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.93,
#         "lon": 87.98
#     },
#     "dt": 1564246154,
#     "id": 1492252,
#     "main": {
#         "grnd_level": 955.3,
#         "humidity": 94,
#         "pressure": 1009.28,
#         "sea_level": 1009.28,
#         "temp": 51.89,
#         "temp_max": 51.89,
#         "temp_min": 51.89
#     },
#     "name": "Sheregesh",
#     "sys": {
#         "country": "RU",
#         "message": 0.0066,
#         "sunrise": 1564179429,
#         "sunset": 1564236706
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 185.958,
#         "speed": 1.19
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.77,
#         "lon": 30.8
#     },
#     "dt": 1564246154,
#     "id": 513898,
#     "main": {
#         "humidity": 51,
#         "pressure": 1015,
#         "temp": 79.41,
#         "temp_max": 80.6,
#         "temp_min": 78.01
#     },
#     "name": "Otradnoye",
#     "sys": {
#         "country": "RU",
#         "id": 8926,
#         "message": 0.0085,
#         "sunrise": 1564190796,
#         "sunset": 1564252786,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 13.42
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38.31,
#         "lon": -60.23
#     },
#     "dt": 1564246154,
#     "id": 3833859,
#     "main": {
#         "grnd_level": 1014.8,
#         "humidity": 36,
#         "pressure": 1026.44,
#         "sea_level": 1026.44,
#         "temp": 56.21,
#         "temp_max": 56.21,
#         "temp_min": 56.21
#     },
#     "name": "Barrow",
#     "sys": {
#         "country": "AR",
#         "message": 0.0053,
#         "sunrise": 1564225600,
#         "sunset": 1564261676
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 148.505,
#         "speed": 3.06
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 38
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -41.05,
#         "lon": 145.91
#     },
#     "dt": 1564246155,
#     "id": 2173125,
#     "main": {
#         "humidity": 95,
#         "pressure": 1016,
#         "temp": 40.08,
#         "temp_max": 44.01,
#         "temp_min": 37
#     },
#     "name": "Burnie",
#     "rain": {
#         "3h": 0.187
#     },
#     "sys": {
#         "country": "AU",
#         "id": 267929,
#         "message": 0.0086,
#         "sunrise": 1564262894,
#         "sunset": 1564298235,
#         "type": 3
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 181,
#         "gust": 1.34,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.24
#     },
#     "dt": 1564245957,
#     "id": 3366880,
#     "main": {
#         "humidity": 95,
#         "pressure": 1009,
#         "temp": 55.04,
#         "temp_max": 55.99,
#         "temp_min": 54
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "message": 0.0057,
#         "sunrise": 1564206032,
#         "sunset": 1564243098,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 121.307,
#         "speed": 6.4
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.29,
#         "lon": 97.04
#     },
#     "dt": 1564246155,
#     "id": 1528998,
#     "main": {
#         "grnd_level": 849.76,
#         "humidity": 21,
#         "pressure": 1006.03,
#         "sea_level": 1006.03,
#         "temp": 72.59,
#         "temp_max": 72.59,
#         "temp_min": 72.59
#     },
#     "name": "Yumen",
#     "sys": {
#         "country": "CN",
#         "message": 0.0065,
#         "sunrise": 1564266304,
#         "sunset": 1564318283
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 60.206,
#         "speed": 9.95
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 3
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1564246139,
#     "id": 4020109,
#     "main": {
#         "grnd_level": 1014.15,
#         "humidity": 77,
#         "pressure": 1014.04,
#         "sea_level": 1014.04,
#         "temp": 80.33,
#         "temp_max": 80.33,
#         "temp_min": 80.33
#     },
#     "name": "Atuona",
#     "rain": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "PF",
#         "message": 0.0074,
#         "sunrise": 1564241563,
#         "sunset": 1564283537
#     },
#     "timezone": -34200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 100.162,
#         "speed": 22.79
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 32
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -31.43,
#         "lon": 152.91
#     },
#     "dt": 1564246155,
#     "id": 2152659,
#     "main": {
#         "humidity": 87,
#         "pressure": 1022,
#         "temp": 50.41,
#         "temp_max": 51.01,
#         "temp_min": 50
#     },
#     "name": "Port Macquarie",
#     "sys": {
#         "country": "AU",
#         "id": 9610,
#         "message": 0.0062,
#         "sunrise": 1564259972,
#         "sunset": 1564297797,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 6.93
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 73
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 33.72,
#         "lon": 135.99
#     },
#     "dt": 1564246155,
#     "id": 1847947,
#     "main": {
#         "grnd_level": 940.98,
#         "humidity": 98,
#         "pressure": 1012.42,
#         "sea_level": 1012.42,
#         "temp": 68.09,
#         "temp_max": 68.09,
#         "temp_min": 68.09
#     },
#     "name": "Shingu",
#     "sys": {
#         "country": "JP",
#         "message": 0.0102,
#         "sunrise": 1564257871,
#         "sunset": 1564308020
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 155.738,
#         "speed": 2.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 27
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.64,
#         "lon": 115.35
#     },
#     "dt": 1564246156,
#     "id": 2075265,
#     "main": {
#         "humidity": 61,
#         "pressure": 1015,
#         "temp": 44.33,
#         "temp_max": 48,
#         "temp_min": 39.99
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2011706,
#         "message": 0.0072,
#         "sunrise": 1564269240,
#         "sunset": 1564306557,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 147.189,
#         "speed": 12.91
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.97,
#         "lon": 22.13
#     },
#     "dt": 1564246156,
#     "id": 1014034,
#     "main": {
#         "grnd_level": 873.54,
#         "humidity": 19,
#         "pressure": 1018.47,
#         "sea_level": 1018.47,
#         "temp": 60.53,
#         "temp_max": 60.53,
#         "temp_min": 60.53
#     },
#     "name": "Carnarvon",
#     "sys": {
#         "country": "ZA",
#         "message": 0.0073,
#         "sunrise": 1564204930,
#         "sunset": 1564242813
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 355.161,
#         "speed": 12.33
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.08,
#         "lon": -159.32
#     },
#     "dt": 1564246156,
#     "id": 5848280,
#     "main": {
#         "humidity": 74,
#         "pressure": 1017,
#         "temp": 75.04,
#         "temp_max": 78.8,
#         "temp_min": 73
#     },
#     "name": "Kapaa",
#     "sys": {
#         "country": "US",
#         "id": 7873,
#         "message": 0.0068,
#         "sunrise": 1564243643,
#         "sunset": 1564291196,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.82,
#         "lon": -51.19
#     },
#     "dt": 1564246156,
#     "id": 3420768,
#     "main": {
#         "humidity": 66,
#         "pressure": 1014,
#         "temp": 48.2,
#         "temp_max": 48.2,
#         "temp_min": 48.2
#     },
#     "name": "Qasigiannguit",
#     "sys": {
#         "country": "GL",
#         "id": 165,
#         "message": 0.0061,
#         "sunrise": 1564202916,
#         "sunset": 1564280021,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 6.93
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 73
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.78,
#         "lon": 100.78
#     },
#     "dt": 1564246156,
#     "id": 1608452,
#     "main": {
#         "grnd_level": 938.37,
#         "humidity": 99,
#         "pressure": 1009.07,
#         "sea_level": 1009.07,
#         "temp": 67.19,
#         "temp_max": 67.19,
#         "temp_min": 67.19
#     },
#     "name": "Nan",
#     "sys": {
#         "country": "TH",
#         "message": 0.0064,
#         "sunrise": 1564181526,
#         "sunset": 1564228465
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 165.669,
#         "speed": 0.31
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.89,
#         "lon": -109.91
#     },
#     "dt": 1564245996,
#     "id": 3985710,
#     "main": {
#         "humidity": 49,
#         "pressure": 1016,
#         "temp": 88.72,
#         "temp_max": 93.99,
#         "temp_min": 79
#     },
#     "name": "Cabo San Lucas",
#     "sys": {
#         "country": "MX",
#         "id": 7151,
#         "message": 0.0068,
#         "sunrise": 1564231700,
#         "sunset": 1564279423,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 8.13,
#         "lon": 77.3
#     },
#     "dt": 1564246157,
#     "id": 1263942,
#     "main": {
#         "humidity": 94,
#         "pressure": 1010,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Manavalakurichi",
#     "sys": {
#         "country": "IN",
#         "id": 9226,
#         "message": 0.006,
#         "sunrise": 1564188128,
#         "sunset": 1564233134,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 3000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 79
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.1,
#         "lon": 173.78
#     },
#     "dt": 1564246157,
#     "id": 2189343,
#     "main": {
#         "humidity": 100,
#         "pressure": 1022,
#         "temp": 51.01,
#         "temp_max": 51.01,
#         "temp_min": 51.01
#     },
#     "name": "Kaeo",
#     "rain": {
#         "3h": 0.125
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2016422,
#         "message": 0.0125,
#         "sunrise": 1564255402,
#         "sunset": 1564292349,
#         "type": 3
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 80.903,
#         "speed": 11.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.1,
#         "lon": -79.12
#     },
#     "dt": 1564246157,
#     "id": 6087892,
#     "main": {
#         "humidity": 54,
#         "pressure": 1022,
#         "temp": 82.49,
#         "temp_max": 86,
#         "temp_min": 78.8
#     },
#     "name": "Niagara Falls",
#     "sys": {
#         "country": "CA",
#         "id": 917,
#         "message": 0.0094,
#         "sunrise": 1564221693,
#         "sunset": 1564274650,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "gust": 9.3,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.48,
#         "lon": -73.76
#     },
#     "dt": 1564246157,
#     "id": 3896218,
#     "main": {
#         "humidity": 87,
#         "pressure": 1021,
#         "temp": 44.6,
#         "temp_max": 44.6,
#         "temp_min": 44.6
#     },
#     "name": "Castro",
#     "sys": {
#         "country": "CL",
#         "id": 8512,
#         "message": 0.0067,
#         "sunrise": 1564229455,
#         "sunset": 1564264316,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 6.8,
#         "lon": -58.16
#     },
#     "dt": 1564246050,
#     "id": 3378644,
#     "main": {
#         "humidity": 70,
#         "pressure": 1014,
#         "temp": 85.17,
#         "temp_max": 86,
#         "temp_min": 84.2
#     },
#     "name": "Georgetown",
#     "sys": {
#         "country": "GY",
#         "id": 8776,
#         "message": 0.0076,
#         "sunrise": 1564220756,
#         "sunset": 1564265527,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity shower rain",
#             "icon": "09d",
#             "id": 520,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.59,
#         "lon": 26.89
#     },
#     "dt": 1564246158,
#     "id": 964432,
#     "main": {
#         "humidity": 71,
#         "pressure": 1014,
#         "temp": 63,
#         "temp_max": 63,
#         "temp_min": 63
#     },
#     "name": "Port Alfred",
#     "sys": {
#         "country": "ZA",
#         "id": 2011314,
#         "message": 0.0071,
#         "sunrise": 1564204096,
#         "sunset": 1564241363,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "gust": 4.47,
#         "speed": 5.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1564246056,
#     "id": 1015776,
#     "main": {
#         "humidity": 87,
#         "pressure": 1013,
#         "temp": 54.86,
#         "temp_max": 57.2,
#         "temp_min": 53.01
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "message": 0.0065,
#         "sunrise": 1564205854,
#         "sunset": 1564242893,
#         "type": 1
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.12,
#         "lon": -88.65
#     },
#     "dt": 1564246158,
#     "id": 4902567,
#     "main": {
#         "humidity": 58,
#         "pressure": 1022,
#         "temp": 83.23,
#         "temp_max": 84.99,
#         "temp_min": 81
#     },
#     "name": "De Land",
#     "sys": {
#         "country": "US",
#         "id": 6026,
#         "message": 0.0149,
#         "sunrise": 1564224469,
#         "sunset": 1564276449,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "gust": 8.2,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -11,
#         "lon": -66.08
#     },
#     "dt": 1564246158,
#     "id": 3906466,
#     "main": {
#         "humidity": 47,
#         "pressure": 1021,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Riberalta",
#     "sys": {
#         "country": "BO",
#         "id": 8629,
#         "message": 0.0064,
#         "sunrise": 1564224160,
#         "sunset": 1564265924,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 78.22,
#         "lon": 15.63
#     },
#     "dt": 1564246081,
#     "id": 2729907,
#     "main": {
#         "humidity": 54,
#         "pressure": 1032,
#         "temp": 55.4,
#         "temp_max": 55.4,
#         "temp_min": 55.4
#     },
#     "name": "Longyearbyen",
#     "sys": {
#         "country": "NO",
#         "id": 1663,
#         "message": 0.014,
#         "sunrise": 0,
#         "sunset": 0,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 4.7
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.63,
#         "lon": -46
#     },
#     "dt": 1564246159,
#     "id": 3453439,
#     "main": {
#         "grnd_level": 912.59,
#         "humidity": 34,
#         "pressure": 1020.65,
#         "sea_level": 1020.65,
#         "temp": 75.65,
#         "temp_max": 75.65,
#         "temp_min": 75.65
#     },
#     "name": "Ponta do Sol",
#     "sys": {
#         "country": "BR",
#         "message": 0.0081,
#         "sunrise": 1564220208,
#         "sunset": 1564260237
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 66.59,
#         "speed": 5.26
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.35,
#         "lon": -158.09
#     },
#     "dt": 1564246159,
#     "id": 5850554,
#     "main": {
#         "humidity": 88,
#         "pressure": 1017,
#         "temp": 74.73,
#         "temp_max": 78.8,
#         "temp_min": 69.8
#     },
#     "name": "Makakilo City",
#     "sys": {
#         "country": "US",
#         "id": 7866,
#         "message": 0.0055,
#         "sunrise": 1564243420,
#         "sunset": 1564290829,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -1.2,
#         "lon": -46.02
#     },
#     "dt": 1564246159,
#     "id": 3402648,
#     "main": {
#         "grnd_level": 1011.35,
#         "humidity": 68,
#         "pressure": 1012.41,
#         "sea_level": 1012.41,
#         "temp": 84.11,
#         "temp_max": 84.11,
#         "temp_min": 84.11
#     },
#     "name": "Carutapera",
#     "rain": {
#         "3h": 0.874
#     },
#     "sys": {
#         "country": "BR",
#         "message": 0.0061,
#         "sunrise": 1564218517,
#         "sunset": 1564261938
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 85.747,
#         "speed": 11.86
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.42,
#         "lon": 3.91
#     },
#     "dt": 1564246159,
#     "id": 2980080,
#     "main": {
#         "humidity": 68,
#         "pressure": 1003,
#         "temp": 67.84,
#         "temp_max": 71.6,
#         "temp_min": 64.99
#     },
#     "name": "Saint-Francois",
#     "rain": {
#         "3h": 6.438
#     },
#     "sys": {
#         "country": "FR",
#         "id": 6499,
#         "message": 0.0087,
#         "sunrise": 1564201138,
#         "sunset": 1564255351,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 12.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 85
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.92,
#         "lon": 159.24
#     },
#     "dt": 1564246160,
#     "id": 2125693,
#     "main": {
#         "grnd_level": 981.33,
#         "humidity": 94,
#         "pressure": 999.7,
#         "sea_level": 999.7,
#         "temp": 45.05,
#         "temp_max": 45.05,
#         "temp_min": 45.05
#     },
#     "name": "Evensk",
#     "sys": {
#         "country": "RU",
#         "message": 0.0056,
#         "sunrise": 1564245418,
#         "sunset": 1564309313
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 78.488,
#         "speed": 3.74
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.28,
#         "lon": -126.83
#     },
#     "dt": 1564246160,
#     "id": 6089245,
#     "main": {
#         "humidity": 62,
#         "pressure": 1012,
#         "temp": 53.6,
#         "temp_max": 53.6,
#         "temp_min": 53.6
#     },
#     "name": "Norman Wells",
#     "sys": {
#         "country": "CA",
#         "id": 951,
#         "message": 0.0086,
#         "sunrise": 1564225431,
#         "sunset": 1564293813,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 48279,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.71,
#         "lon": -155.08
#     },
#     "dt": 1564246160,
#     "id": 5855927,
#     "main": {
#         "humidity": 94,
#         "pressure": 1017,
#         "temp": 69.4,
#         "temp_max": 73,
#         "temp_min": 66
#     },
#     "name": "Hilo",
#     "rain": {
#         "1h": 0.76
#     },
#     "sys": {
#         "country": "US",
#         "id": 7881,
#         "message": 0.0062,
#         "sunrise": 1564242858,
#         "sunset": 1564289946,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.7,
#         "lon": -127.42
#     },
#     "dt": 1564246160,
#     "id": 6111862,
#     "main": {
#         "humidity": 87,
#         "pressure": 1022,
#         "temp": 60.8,
#         "temp_max": 60.8,
#         "temp_min": 60.8
#     },
#     "name": "Port Hardy",
#     "sys": {
#         "country": "CA",
#         "id": 1011,
#         "message": 0.0077,
#         "sunrise": 1564231752,
#         "sunset": 1564287776,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 32186,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09d",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.91,
#         "lon": -46.05
#     },
#     "dt": 1564246160,
#     "id": 3421719,
#     "main": {
#         "humidity": 48,
#         "pressure": 1014,
#         "temp": 62.6,
#         "temp_max": 62.6,
#         "temp_min": 62.6
#     },
#     "name": "Narsaq",
#     "sys": {
#         "country": "GL",
#         "id": 47,
#         "message": 0.0061,
#         "sunrise": 1564208739,
#         "sunset": 1564271731,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.81,
#         "lon": -68.31
#     },
#     "dt": 1564246161,
#     "id": 3833367,
#     "main": {
#         "humidity": 86,
#         "pressure": 996,
#         "temp": 41,
#         "temp_max": 41,
#         "temp_min": 41
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "message": 0.006,
#         "sunrise": 1564230676,
#         "sunset": 1564260478,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.97,
#         "lon": -114.04
#     },
#     "dt": 1564246124,
#     "id": 4021858,
#     "main": {
#         "grnd_level": 1014.95,
#         "humidity": 78,
#         "pressure": 1014.49,
#         "sea_level": 1014.49,
#         "temp": 70.79,
#         "temp_max": 70.79,
#         "temp_min": 70.79
#     },
#     "name": "Guerrero Negro",
#     "sys": {
#         "country": "MX",
#         "message": 0.0074,
#         "sunrise": 1564232151,
#         "sunset": 1564280954
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 328.933,
#         "speed": 9.78
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.95,
#         "lon": -94.76
#     },
#     "dt": 1564246161,
#     "id": 4407665,
#     "main": {
#         "humidity": 57,
#         "pressure": 1022,
#         "temp": 82.18,
#         "temp_max": 84.99,
#         "temp_min": 80.6
#     },
#     "name": "Kodiak",
#     "sys": {
#         "country": "US",
#         "id": 4042,
#         "message": 0.0072,
#         "sunrise": 1564225963,
#         "sunset": 1564277888,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "haze",
#             "icon": "50d",
#             "id": 721,
#             "main": "Haze"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.97,
#         "lon": -42.02
#     },
#     "dt": 1564246048,
#     "id": 3471451,
#     "main": {
#         "humidity": 57,
#         "pressure": 1022,
#         "temp": 78.75,
#         "temp_max": 80.6,
#         "temp_min": 77
#     },
#     "name": "Arraial do Cabo",
#     "sys": {
#         "country": "BR",
#         "id": 8326,
#         "message": 0.0069,
#         "sunrise": 1564219479,
#         "sunset": 1564259056,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 16.11
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.79,
#         "lon": -161.76
#     },
#     "dt": 1564246161,
#     "id": 5880568,
#     "main": {
#         "humidity": 87,
#         "pressure": 1011,
#         "temp": 48.13,
#         "temp_max": 51.8,
#         "temp_min": 44.6
#     },
#     "name": "Bethel",
#     "sys": {
#         "country": "US",
#         "id": 7640,
#         "message": 0.0073,
#         "sunrise": 1564236614,
#         "sunset": 1564299396,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 169.765,
#         "speed": 6.35
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.7,
#         "lon": 30.79
#     },
#     "dt": 1564246162,
#     "id": 546105,
#     "main": {
#         "humidity": 51,
#         "pressure": 1015,
#         "temp": 79.39,
#         "temp_max": 80.6,
#         "temp_min": 78.01
#     },
#     "name": "Nikolskoye",
#     "sys": {
#         "country": "RU",
#         "id": 8926,
#         "message": 0.0069,
#         "sunrise": 1564190829,
#         "sunset": 1564252757,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 13.42
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 26.54,
#         "lon": -78.7
#     },
#     "dt": 1564246041,
#     "id": 3572375,
#     "main": {
#         "humidity": 70,
#         "pressure": 1022,
#         "temp": 87.8,
#         "temp_max": 87.8,
#         "temp_min": 87.8
#     },
#     "name": "Freeport",
#     "sys": {
#         "country": "BS",
#         "id": 7260,
#         "message": 0.0084,
#         "sunrise": 1564223823,
#         "sunset": 1564272318,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.61,
#         "lon": -37.64
#     },
#     "dt": 1564246162,
#     "id": 3424607,
#     "main": {
#         "humidity": 62,
#         "pressure": 1017,
#         "temp": 51.8,
#         "temp_max": 51.8,
#         "temp_min": 51.8
#     },
#     "name": "Tasiilaq",
#     "sys": {
#         "country": "GL",
#         "id": 81,
#         "message": 0.0083,
#         "sunrise": 1564203693,
#         "sunset": 1564272740,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.93,
#         "lon": 18.42
#     },
#     "dt": 1564246077,
#     "id": 3369157,
#     "main": {
#         "humidity": 93,
#         "pressure": 1013,
#         "temp": 56.93,
#         "temp_max": 59,
#         "temp_min": 55
#     },
#     "name": "Cape Town",
#     "sys": {
#         "country": "ZA",
#         "id": 1899,
#         "message": 0.0067,
#         "sunrise": 1564206169,
#         "sunset": 1564243355,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.16,
#         "lon": -70.91
#     },
#     "dt": 1564246162,
#     "id": 3874787,
#     "main": {
#         "humidity": 75,
#         "pressure": 1002,
#         "temp": 44.4,
#         "temp_max": 44.6,
#         "temp_min": 44.01
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "message": 0.0072,
#         "sunrise": 1564230867,
#         "sunset": 1564261536,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "speed": 26.4
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 56
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.68,
#         "lon": -86.92
#     },
#     "dt": 1564246163,
#     "id": 3609418,
#     "main": {
#         "grnd_level": 913.23,
#         "humidity": 39,
#         "pressure": 1015.35,
#         "sea_level": 1015.35,
#         "temp": 85.73,
#         "temp_max": 85.73,
#         "temp_min": 85.73
#     },
#     "name": "San Cristobal",
#     "sys": {
#         "country": "HN",
#         "message": 0.0054,
#         "sunrise": 1564226967,
#         "sunset": 1564273121
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 75.892,
#         "speed": 11.68
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 71
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.66,
#         "lon": 137.31
#     },
#     "dt": 1564246163,
#     "id": 1849876,
#     "main": {
#         "humidity": 99,
#         "pressure": 1011,
#         "temp": 74.98,
#         "temp_max": 75.99,
#         "temp_min": 73.99
#     },
#     "name": "Tateyama",
#     "sys": {
#         "country": "JP",
#         "id": 2011552,
#         "message": 0.01,
#         "sunrise": 1564257164,
#         "sunset": 1564308093,
#         "type": 3
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 223.123,
#         "speed": 4.92
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.95,
#         "lon": 153.24
#     },
#     "dt": 1564246163,
#     "id": 2160063,
#     "main": {
#         "humidity": 93,
#         "pressure": 1021,
#         "temp": 50.13,
#         "temp_max": 54,
#         "temp_min": 46.4
#     },
#     "name": "Codrington",
#     "sys": {
#         "country": "AU",
#         "id": 9537,
#         "message": 0.0095,
#         "sunrise": 1564259617,
#         "sunset": 1564297993,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 150,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 206.706,
#         "speed": 1.23
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.21,
#         "lon": -70.48
#     },
#     "dt": 1564246163,
#     "id": 6137631,
#     "main": {
#         "humidity": 53,
#         "pressure": 1021,
#         "temp": 82,
#         "temp_max": 82,
#         "temp_min": 82
#     },
#     "name": "Saint-Prosper",
#     "sys": {
#         "country": "CA",
#         "id": 2003732,
#         "message": 0.0092,
#         "sunrise": 1564219047,
#         "sunset": 1564273149,
#         "type": 3
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 262,
#         "gust": 4.47,
#         "speed": 5.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 23.99,
#         "lon": -104.67
#     },
#     "dt": 1564246163,
#     "id": 4011743,
#     "main": {
#         "humidity": 43,
#         "pressure": 1029,
#         "temp": 71.26,
#         "temp_max": 73,
#         "temp_min": 69.8
#     },
#     "name": "Constitucion",
#     "sys": {
#         "country": "MX",
#         "id": 7113,
#         "message": 0.0065,
#         "sunrise": 1564230329,
#         "sunset": 1564278279,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 19312,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 73.119,
#         "speed": 11.12
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.15,
#         "lon": -123.21
#     },
#     "dt": 1564245954,
#     "id": 5404476,
#     "main": {
#         "humidity": 53,
#         "pressure": 1018,
#         "temp": 69.78,
#         "temp_max": 82.99,
#         "temp_min": 55.99
#     },
#     "name": "Ukiah",
#     "sys": {
#         "country": "US",
#         "id": 6129,
#         "message": 0.0089,
#         "sunrise": 1564232916,
#         "sunset": 1564284590,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 239.077,
#         "speed": 5.39
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 60
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.58,
#         "lon": 150.85
#     },
#     "dt": 1564246164,
#     "id": 6255012,
#     "main": {
#         "humidity": 100,
#         "pressure": 1023,
#         "temp": 48.88,
#         "temp_max": 53.01,
#         "temp_min": 45
#     },
#     "name": "Flinders",
#     "sys": {
#         "country": "AU",
#         "id": 9594,
#         "message": 0.0075,
#         "sunrise": 1564260839,
#         "sunset": 1564297919,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.72,
#         "lon": -25.43
#     },
#     "dt": 1564246164,
#     "id": 3372472,
#     "main": {
#         "humidity": 88,
#         "pressure": 1024,
#         "temp": 75.2,
#         "temp_max": 75.2,
#         "temp_min": 75.2
#     },
#     "name": "Vila Franca do Campo",
#     "sys": {
#         "country": "PT",
#         "id": 6899,
#         "message": 0.0074,
#         "sunrise": 1564209645,
#         "sunset": 1564260927,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 17.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.93,
#         "lon": 152.39
#     },
#     "dt": 1564246075,
#     "id": 2121373,
#     "main": {
#         "grnd_level": 950.74,
#         "humidity": 88,
#         "pressure": 1000.11,
#         "sea_level": 1000.11,
#         "temp": 53.15,
# ...
#         "country": "AU",
#         "id": 9594,
#         "message": 0.0084,
#         "sunrise": 1564260847,
#         "sunset": 1564297906,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 39
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.93,
#         "lon": 96.16
#     },
#     "dt": 1564246267,
#     "id": 1254709,
#     "main": {
#         "grnd_level": 953.51,
#         "humidity": 95,
#         "pressure": 1009.36,
#         "sea_level": 1009.36,
#         "temp": 73.49,
#         "temp_max": 73.49,
#         "temp_min": 73.49
#     },
#     "name": "Tezu",
#     "rain": {
#         "3h": 2.063
#     },
#     "sys": {
#         "country": "IN",
#         "message": 0.0057,
#         "sunrise": 1564181688,
#         "sunset": 1564230521
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 38.231,
#         "speed": 3.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 8.58,
#         "lon": 81.23
#     },
#     "dt": 1564246267,
#     "id": 1226260,
#     "main": {
#         "grnd_level": 1000.35,
#         "humidity": 77,
#         "pressure": 1009.07,
#         "sea_level": 1009.07,
#         "temp": 78.35,
#         "temp_max": 78.35,
#         "temp_min": 78.35
#     },
#     "name": "Trincomalee",
#     "sys": {
#         "country": "LK",
#         "message": 0.0061,
#         "sunrise": 1564187146,
#         "sunset": 1564232230
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 241.483,
#         "speed": 9.08
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.65,
#         "lon": -115.58
#     },
#     "dt": 1564246267,
#     "id": 5921525,
#     "main": {
#         "humidity": 82,
#         "pressure": 1009,
#         "temp": 59,
#         "temp_max": 59,
#         "temp_min": 59
#     },
#     "name": "Mackay",
#     "sys": {
#         "country": "CA",
#         "id": 1012,
#         "message": 0.0064,
#         "sunrise": 1564228135,
#         "sunset": 1564285709,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.32,
#         "lon": 155.48
#     },
#     "dt": 1564246267,
#     "id": 2088659,
#     "main": {
#         "grnd_level": 1008.95,
#         "humidity": 82,
#         "pressure": 1008.98,
#         "sea_level": 1008.98,
#         "temp": 79.79,
#         "temp_max": 79.79,
#         "temp_min": 79.79
#     },
#     "name": "Panguna",
#     "sys": {
#         "country": "PG",
#         "message": 0.0055,
#         "sunrise": 1564256984,
#         "sunset": 1564299551
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 121.536,
#         "speed": 10.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.46,
#         "lon": 25.83
#     },
#     "dt": 1564246268,
#     "id": 912628,
#     "main": {
#         "grnd_level": 881.38,
#         "humidity": 35,
#         "pressure": 1017.71,
#         "sea_level": 1017.71,
#         "temp": 60.17,
#         "temp_max": 60.17,
#         "temp_min": 60.17
#     },
#     "name": "Kasempa",
#     "sys": {
#         "country": "ZM",
#         "message": 0.0074,
#         "sunrise": 1564202319,
#         "sunset": 1564243648
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 121.442,
#         "speed": 5.53
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 39
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -18.77,
#         "lon": 46.05
#     },
#     "dt": 1564246268,
#     "id": 1054463,
#     "main": {
#         "grnd_level": 926.05,
#         "humidity": 52,
#         "pressure": 1018.93,
#         "sea_level": 1018.93,
#         "temp": 62.69,
#         "temp_max": 62.69,
#         "temp_min": 62.69
#     },
#     "name": "Tsiroanomandidy",
#     "sys": {
#         "country": "MG",
#         "message": 0.006,
#         "sunrise": 1564197947,
#         "sunset": 1564238314
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 50.49,
#         "speed": 4.83
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 49
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 26,
#         "lon": 92.85
#     },
#     "dt": 1564246268,
#     "id": 1269993,
#     "main": {
#         "grnd_level": 964.66,
#         "humidity": 88,
#         "pressure": 1005.09,
#         "sea_level": 1005.09,
#         "temp": 74.21,
#         "temp_max": 74.21,
#         "temp_min": 74.21
#     },
#     "name": "Hojai",
#     "rain": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "IN",
#         "message": 0.0058,
#         "sunrise": 1564182695,
#         "sunset": 1564231102
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 223.864,
#         "speed": 4.14
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# Missing field/result... skipping.
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 67.67,
#         "lon": 12.69
#     },
#     "dt": 1564246268,
#     "id": 3137469,
#     "main": {
#         "humidity": 56,
#         "pressure": 1021,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Sorland",
#     "sys": {
#         "country": "NO",
#         "id": 1642,
#         "message": 0.006,
#         "sunrise": 1564189381,
#         "sunset": 1564262894,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "speed": 16.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 41
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.13,
#         "lon": 74.84
#     },
#     "dt": 1564246268,
#     "id": 1500399,
#     "main": {
#         "grnd_level": 995.23,
#         "humidity": 73,
#         "pressure": 1000.48,
#         "sea_level": 1000.48,
#         "temp": 52.25,
#         "temp_max": 52.25,
#         "temp_min": 52.25
#     },
#     "name": "Lokosovo",
#     "sys": {
#         "country": "RU",
#         "message": 0.0067,
#         "sunrise": 1564179567,
#         "sunset": 1564242876
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 278.29,
#         "speed": 7.49
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 50
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -31.63,
#         "lon": -71.17
#     },
#     "dt": 1564246269,
#     "id": 3887344,
#     "main": {
#         "grnd_level": 979.28,
#         "humidity": 55,
#         "pressure": 1016.86,
#         "sea_level": 1016.86,
#         "temp": 59.45,
#         "temp_max": 59.45,
#         "temp_min": 59.45
#     },
#     "name": "Illapel",
#     "sys": {
#         "country": "CL",
#         "message": 0.0064,
#         "sunrise": 1564227388,
#         "sunset": 1564265139
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 223.172,
#         "speed": 7.54
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.87,
#         "lon": -73.43
#     },
#     "dt": 1564246079,
#     "id": 5121636,
#     "main": {
#         "humidity": 69,
#         "pressure": 1024,
#         "temp": 82.45,
#         "temp_max": 87.01,
#         "temp_min": 78.01
#     },
#     "name": "Huntington",
#     "sys": {
#         "country": "US",
#         "id": 3409,
#         "message": 0.0117,
#         "sunrise": 1564220696,
#         "sunset": 1564272916,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "thunderstorm",
#             "icon": "11d",
#             "id": 211,
#             "main": "Thunderstorm"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.72,
#         "lon": 8.78
#     },
#     "dt": 1564246269,
#     "id": 2396518,
#     "main": {
#         "humidity": 83,
#         "pressure": 1012,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Port-Gentil",
#     "sys": {
#         "country": "GA",
#         "id": 2188,
#         "message": 0.0068,
#         "sunrise": 1564205325,
#         "sunset": 1564248826,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 12.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 45.63,
#         "lon": -73.98
#     },
#     "dt": 1564246269,
#     "id": 6138501,
#     "main": {
#         "humidity": 48,
#         "pressure": 1022,
#         "temp": 85.5,
#         "temp_max": 89.01,
#         "temp_min": 84
#     },
#     "name": "Saint-Augustin",
#     "sys": {
#         "country": "CA",
#         "id": 943,
#         "message": 0.01,
#         "sunrise": 1564220000,
#         "sunset": 1564273876,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 46
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.38,
#         "lon": 8.97
#     },
#     "dt": 1564246269,
#     "id": 2854655,
#     "main": {
#         "humidity": 32,
#         "pressure": 1002,
#         "temp": 83.44,
#         "temp_max": 84.99,
#         "temp_min": 80.01
#     },
#     "name": "Petershagen",
#     "sys": {
#         "country": "DE",
#         "id": 1820,
#         "message": 0.0223,
#         "sunrise": 1564198560,
#         "sunset": 1564255500,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 4300,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 17.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -45.41,
#         "lon": 167.72
#     },
#     "dt": 1564246270,
#     "id": 2181625,
#     "main": {
#         "grnd_level": 964.79,
#         "humidity": 83,
#         "pressure": 1019.38,
#         "sea_level": 1019.38,
#         "temp": 45.95,
#         "temp_max": 45.95,
#         "temp_min": 45.95
#     },
#     "name": "Te Anau",
#     "sys": {
#         "country": "NZ",
#         "message": 0.0057,
#         "sunrise": 1564258362,
#         "sunset": 1564292298
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 325.686,
#         "speed": 4.5
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.98,
#         "lon": -123.82
#     },
#     "dt": 1564245971,
#     "id": 5785243,
#     "main": {
#         "humidity": 88,
#         "pressure": 1024,
#         "temp": 65.46,
#         "temp_max": 68,
#         "temp_min": 63
#     },
#     "name": "Aberdeen",
#     "sys": {
#         "country": "US",
#         "id": 4406,
#         "message": 0.0068,
#         "sunrise": 1564231707,
#         "sunset": 1564286093,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 12874,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.91,
#         "lon": -15.45
#     },
#     "dt": 1564246270,
#     "id": 2522325,
#     "main": {
#         "humidity": 57,
#         "pressure": 1016,
#         "temp": 77.86,
#         "temp_max": 78.8,
#         "temp_min": 77
#     },
#     "name": "Aguimes",
#     "sys": {
#         "country": "ES",
#         "id": 2378,
#         "message": 0.0064,
#         "sunrise": 1564208487,
#         "sunset": 1564257295,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 31.09
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -16.99,
#         "lon": 145.42
#     },
#     "dt": 1564246270,
#     "id": 2158767,
#     "main": {
#         "humidity": 77,
#         "pressure": 1018,
#         "temp": 66.33,
#         "temp_max": 69.8,
#         "temp_min": 59
#     },
#     "name": "Mareeba",
#     "sys": {
#         "country": "AU",
#         "id": 9490,
#         "message": 0.0069,
#         "sunrise": 1564260321,
#         "sunset": 1564301043,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.98,
#         "lon": 25.97
#     },
#     "dt": 1564246270,
#     "id": 779554,
#     "main": {
#         "grnd_level": 1025.92,
#         "humidity": 87,
#         "pressure": 1028.94,
#         "sea_level": 1028.94,
#         "temp": 45.59,
#         "temp_max": 45.59,
#         "temp_min": 45.59
#     },
#     "name": "Honningsvag",
#     "sys": {
#         "country": "NO",
#         "message": 0.0062,
#         "sunrise": 0,
#         "sunset": 0
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 43.965,
#         "speed": 13.85
#     }
# }

# %%
Record={"city":city, "date":Date,"latitude":lat,"longitude":lngs,"Humidity":humidity,"Max_temp":Max_temp,"Wind_speed":Wind_speed}
Record
# Out:
# {'city': 'honningsvag',
#  'date': 1564246270,
#  'latitude': 70.98,
#  'longitude': 25.97,
#  'Humidity': 87,
#  'Max_temp': 45.59,
#  'Wind_speed': 13.85}

# %%
citydata.append(Record)

# %%
Equator_nearby=pd.DataFrame(citydata)
Equator_nearby.head()
# Out:
#    Humidity  Max_temp  Wind_speed          city        date  latitude  \
# 0        93     46.00        3.00       mataura  1564246152    -46.19
# 1        81     74.03        9.48       rikitea  1564246152    -23.12
# 2        81     74.03        9.48  attawapiskat  1564246152    -23.12
# 3        62     88.79       11.34   sardarshahr  1564246153     28.43
# 4        62     88.79       11.34   solovetskiy  1564246153     28.43
#
#    longitude
# 0     168.86
# 1    -134.97
# 2    -134.97
# 3      74.48
# 4      74.48

# %%
 Equator_nearby[["city","latitude","longitude","Max_temp","Humidity","Wind_speed", "date"]].head()
# Out:
#            city  latitude  longitude  Max_temp  Humidity  Wind_speed  \
# 0       mataura    -46.19     168.86     46.00        93        3.00
# 1       rikitea    -23.12    -134.97     74.03        81        9.48
# 2  attawapiskat    -23.12    -134.97     74.03        81        9.48
# 3   sardarshahr     28.43      74.48     88.79        62       11.34
# 4   solovetskiy     28.43      74.48     88.79        62       11.34
#
#          date
# 0  1564246152
# 1  1564246152
# 2  1564246152
# 3  1564246153
# 4  1564246153

# %%
Equator_nearby.count()
# Out:
# Humidity      611
# Max_temp      611
# Wind_speed    611
# city          611
# date          611
# latitude      611
# longitude     611
# dtype: int64

# %%
#Plot Temperature(F), Latitude relationship

plt.scatter(Equator_nearby.latitude,Equator_nearby.Max_temp, s= Equator_nearby.Max_temp, facecolors="Gold",edgecolor="black", linewidths=1, marker="o",alpha=0.75)
plt.xlim(-90,90)
plt.ylim(-20, 100)
plt.title("Latitude Vs Temperature(F)")
plt.xlabel("Latitude")
plt.ylabel("Max_Temperature(F)")
plt.text(120,50, "Notes:\n Temperature is high close to the Equator and decrease as you go away from Equator on both direction")
plt.grid()
plt.show()

# %%
#Plot Latitude Vs Humidity plot
plt.scatter(Equator_nearby.latitude,Equator_nearby.Humidity, s= Equator_nearby.Humidity, facecolors="skyblue",edgecolor="black", linewidths=1, marker="o",alpha=0.75)
plt.xlim(-90,90)
plt.ylim(0, 100)
plt.title("Latitude Vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.text(120,50, "Notes:\n Humidity apprears to be higher in the North hemisphere than the south")
plt.grid()

# %%
#Plot Latitude Vs Cloudness plot
plt.scatter(Equator_nearby.latitude,Equator_nearby.Wind_speed, s=10*Equator_nearby.Wind_speed, facecolors="coral",edgecolor="black", linewidths=1, marker="o",alpha=0.75)
plt.xlim(-90,90)
plt.ylim(0, 100)
plt.title("Latitude Vs Wind_speed")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.text(120,50, "Notes:\n The Wind speed is relatively the low and the same around the world, nevertheless seems to increase in the farther North of Equator ")
plt.grid()

# %%
# Out:
# Comment:Fr
